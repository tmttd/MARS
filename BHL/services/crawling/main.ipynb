# %% [markdown]
# # 구현 과제
# 1. 크롤링 기능 하나의 함수로 변환
# 2. 구, 동의 리스트 제작
# 3. 반복문 활용하여 모든 구, 동의 단지명을 DB에 저장
# 4. RAG시스템으로 유효성 검사 구축

# %%
# %pip install timezone
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement timezone (from versions: none)
# ERROR: No matching distribution found for timezone
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pymongo import MongoClient
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
from datetime import datetime, timezone
from bs4 import BeautifulSoup
from config import settings
import time
import json
import os
import logging

# %%
UTC = timezone.utc

# 로깅 설정
logging.basicConfig(level=logging.WARNING)
logger = logging.getLogger(__name__)

# 환경 변수
MONGODB_URI = os.getenv("MONGODB_URI", "mongodb://localhost:27017/")
MONGODB_DB = os.getenv("MONGODB_DB", "converter_db")

try:
    client = MongoClient(MONGODB_URI)
    db = client[MONGODB_DB]
    work_client = MongoClient(settings.WORK_MONGODB_URI)
    work_db = work_client[settings.WORK_MONGODB_DB]
    vocab_db = work_client[settings.VOCAB_MONGODB_DB]
    logger.info("MongoDB 연결 성공")
    print("MongoDB 연결 성공")
except Exception as e:
    logger.error(f"MongoDB 연결 실패: {str(e)}")
    raise
# Out:
# MongoDB 연결 성공

# %%
chrome_options = Options()

# %%
service = Service('./chromedriver-win64/chromedriver.exe')
driver = webdriver.Chrome(service=service, options=chrome_options)
wait = WebDriverWait(driver, 10)

# %%
# 부동산 뱅크 로그인 페이지 이동
driver.get('https://www.neonet.co.kr/novo-rebank/view/member/MemberLogin.neo?login_check=yes&return_url=/novo-rebank/index.neo')

# %%
# 로그인
id_input = driver.find_element(By.XPATH, '//*[@id="input_id"]')
id_input.send_keys('5164980')
pwd_input = driver.find_element(By.XPATH, '//*[@id="input_pw"]')
pwd_input.send_keys('5164980')
button = driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[1]/dl/dt/form/table[1]/tbody/tr[1]/td[2]/input')
button.click()
time.sleep(2)
driver.switch_to.window(driver.window_handles[-1])

# %%
# 매물 등록 페이지로 이동
button_2 = driver.find_element(By.XPATH, '//*[@id="btn_offer_register"]/span/a')
button_2.click()
time.sleep(2)

# %% [markdown]
# # 아파트랑 오피스텔만 크롤링하면 됨.

# %%
# 아파트 단지명 크롤링
property_type = driver.find_element(By.XPATH, '//*[@id="offerings_gbn"]')
property_type_select = Select(property_type)
property_type_select.select_by_value('AT')  # 오피스텔 'op'
time.sleep(1)

# 서울 셀렉
Cities = driver.find_element(By.XPATH, '//*[@id="metro_cd"]')
Cities_select = Select(Cities)
Cities_select.select_by_value('1100000000')
time.sleep(1)

# 구-동-단지 순회
Gus = driver.find_element(By.XPATH, '//*[@id="gu_cd"]')
Gus_select = Select(Gus)

# 구 순회
for gu_option in Gus_select.options[1:]:  # 첫 번째 옵션(선택하세요) 제외
    gu_value = gu_option.get_attribute('value')
    gu_name = gu_option.text
    Gus_select.select_by_value(gu_value)
    time.sleep(1)
    
    # 각 구별 데이터 초기화
    gu_data = {
        '_id': gu_value,  # 구 코드를 id로 사용
        'name': gu_name,
        'created_at': datetime.now(),
        'updated_at': datetime.now(),
        'dongs': {}
    }
    
    # 동 순회
    Dongs = driver.find_element(By.XPATH, '//*[@id="dong_cd"]')
    Dongs_select = Select(Dongs)
    
    for dong_option in Dongs_select.options[1:]:
        dong_value = dong_option.get_attribute('value')
        dong_name = dong_option.text
        Dongs_select.select_by_value(dong_value)
        time.sleep(1)
        
        # 단지명 가져오기
        Danjis = driver.find_element(By.XPATH, '//*[@id="complex_cd"]')
        Danjis_select = Select(Danjis)
        all_Danjis_options = [option.text for option in Danjis_select.options][1:]
        
        # 동별 단지 데이터 저장
        gu_data['dongs'][dong_name] = all_Danjis_options
        
        print(f"크롤링 완료: {gu_name} {dong_name} - {len(all_Danjis_options)}개 단지")

    try:
        # 각 구별로 별도 document로 저장
        vocab_db.seoul.update_one(
            {"_id": gu_value},  # 구 코드로 찾기
            {"$set": gu_data},  # 업데이트할 데이터
            upsert=True  # 없으면 삽입
        )
        print(f"{gu_name} 데이터 저장 완료")
    except Exception as e:
        logger.error(f"데이터 저장 실패: {str(e)}")
        print(f"데이터 저장 실패: {str(e)}")
        raise
# Out:
# 크롤링 완료: 강남구 개포동 - 47개 단지
# 크롤링 완료: 강남구 논현동 - 113개 단지
# 크롤링 완료: 강남구 대치동 - 74개 단지
# 크롤링 완료: 강남구 도곡동 - 77개 단지
# 크롤링 완료: 강남구 삼성동 - 110개 단지
# 크롤링 완료: 강남구 세곡동 - 7개 단지
# 크롤링 완료: 강남구 수서동 - 8개 단지
# 크롤링 완료: 강남구 신사동 - 36개 단지
# 크롤링 완료: 강남구 압구정동 - 21개 단지
# 크롤링 완료: 강남구 역삼동 - 156개 단지
# 크롤링 완료: 강남구 율현동 - 2개 단지
# 크롤링 완료: 강남구 일원동 - 20개 단지
# 크롤링 완료: 강남구 자곡동 - 8개 단지
# 크롤링 완료: 강남구 청담동 - 123개 단지
# 강남구 데이터 저장 완료
# 크롤링 완료: 강동구 강일동 - 15개 단지
# 크롤링 완료: 강동구 고덕동 - 11개 단지
# 크롤링 완료: 강동구 길동 - 129개 단지
# 크롤링 완료: 강동구 둔촌동 - 61개 단지
# 크롤링 완료: 강동구 명일동 - 41개 단지
# 크롤링 완료: 강동구 상일동 - 20개 단지
# 크롤링 완료: 강동구 성내동 - 163개 단지
# 크롤링 완료: 강동구 암사동 - 67개 단지
# 크롤링 완료: 강동구 천호동 - 170개 단지
# 강동구 데이터 저장 완료
# 크롤링 완료: 강북구 미아동 - 44개 단지
# 크롤링 완료: 강북구 번동 - 37개 단지
# 크롤링 완료: 강북구 수유동 - 82개 단지
# 크롤링 완료: 강북구 우이동 - 10개 단지
# 강북구 데이터 저장 완료
# 크롤링 완료: 강서구 가양동 - 33개 단지
# 크롤링 완료: 강서구 공항동 - 36개 단지
# 크롤링 완료: 강서구 내발산동 - 103개 단지
# 크롤링 완료: 강서구 등촌동 - 106개 단지
# 크롤링 완료: 강서구 마곡동 - 44개 단지
# 크롤링 완료: 강서구 방화동 - 96개 단지
# 크롤링 완료: 강서구 염창동 - 87개 단지
# 크롤링 완료: 강서구 화곡동 - 429개 단지
# 강서구 데이터 저장 완료
# 크롤링 완료: 관악구 남현동 - 59개 단지
# 크롤링 완료: 관악구 봉천동 - 204개 단지
# 크롤링 완료: 관악구 신림동 - 151개 단지
# 관악구 데이터 저장 완료
# 크롤링 완료: 광진구 광장동 - 39개 단지
# 크롤링 완료: 광진구 구의동 - 86개 단지
# 크롤링 완료: 광진구 군자동 - 15개 단지
# 크롤링 완료: 광진구 능동 - 9개 단지
# 크롤링 완료: 광진구 자양동 - 97개 단지
# 크롤링 완료: 광진구 중곡동 - 49개 단지
# 크롤링 완료: 광진구 화양동 - 32개 단지
# 광진구 데이터 저장 완료
# 크롤링 완료: 구로구 가리봉동 - 3개 단지
# 크롤링 완료: 구로구 개봉동 - 62개 단지
# 크롤링 완료: 구로구 고척동 - 46개 단지
# 크롤링 완료: 구로구 구로동 - 130개 단지
# 크롤링 완료: 구로구 궁동 - 16개 단지
# 크롤링 완료: 구로구 신도림동 - 28개 단지
# 크롤링 완료: 구로구 오류동 - 64개 단지
# 크롤링 완료: 구로구 온수동 - 16개 단지
# 크롤링 완료: 구로구 천왕동 - 9개 단지
# 크롤링 완료: 구로구 항동 - 12개 단지
# 구로구 데이터 저장 완료
# 크롤링 완료: 금천구 가산동 - 55개 단지
# 크롤링 완료: 금천구 독산동 - 168개 단지
# 크롤링 완료: 금천구 시흥동 - 130개 단지
# 금천구 데이터 저장 완료
# 크롤링 완료: 노원구 공릉동 - 106개 단지
# 크롤링 완료: 노원구 상계동 - 104개 단지
# 크롤링 완료: 노원구 월계동 - 48개 단지
# 크롤링 완료: 노원구 중계동 - 57개 단지
# 크롤링 완료: 노원구 하계동 - 22개 단지
# 노원구 데이터 저장 완료
# 크롤링 완료: 도봉구 도봉동 - 27개 단지
# 크롤링 완료: 도봉구 방학동 - 51개 단지
# 크롤링 완료: 도봉구 쌍문동 - 84개 단지
# 크롤링 완료: 도봉구 창동 - 109개 단지
# 도봉구 데이터 저장 완료
# 크롤링 완료: 동대문구 답십리동 - 46개 단지
# 크롤링 완료: 동대문구 신설동 - 9개 단지
# 크롤링 완료: 동대문구 용두동 - 45개 단지
# 크롤링 완료: 동대문구 이문동 - 30개 단지
# 크롤링 완료: 동대문구 장안동 - 177개 단지
# 크롤링 완료: 동대문구 전농동 - 23개 단지
# 크롤링 완료: 동대문구 제기동 - 23개 단지
# 크롤링 완료: 동대문구 청량리동 - 9개 단지
# 크롤링 완료: 동대문구 회기동 - 12개 단지
# 크롤링 완료: 동대문구 휘경동 - 35개 단지
# 동대문구 데이터 저장 완료
# 크롤링 완료: 동작구 노량진동 - 20개 단지
# 크롤링 완료: 동작구 대방동 - 54개 단지
# 크롤링 완료: 동작구 동작동 - 5개 단지
# 크롤링 완료: 동작구 본동 - 8개 단지
# 크롤링 완료: 동작구 사당동 - 76개 단지
# 크롤링 완료: 동작구 상도1동 - 13개 단지
# 크롤링 완료: 동작구 상도동 - 91개 단지
# 크롤링 완료: 동작구 신대방동 - 34개 단지
# 크롤링 완료: 동작구 흑석동 - 20개 단지
# 동작구 데이터 저장 완료
# 크롤링 완료: 마포구 공덕동 - 21개 단지
# 크롤링 완료: 마포구 구수동 - 1개 단지
# 크롤링 완료: 마포구 노고산동 - 9개 단지
# 크롤링 완료: 마포구 대흥동 - 8개 단지
# 크롤링 완료: 마포구 도화동 - 14개 단지
# 크롤링 완료: 마포구 동교동 - 3개 단지
# 크롤링 완료: 마포구 마포동 - 5개 단지
# 크롤링 완료: 마포구 망원동 - 85개 단지
# 크롤링 완료: 마포구 상수동 - 9개 단지
# 크롤링 완료: 마포구 상암동 - 16개 단지
# 크롤링 완료: 마포구 서교동 - 23개 단지
# 크롤링 완료: 마포구 성산동 - 47개 단지
# 크롤링 완료: 마포구 신공덕동 - 13개 단지
# 크롤링 완료: 마포구 신수동 - 14개 단지
# 크롤링 완료: 마포구 신정동 - 2개 단지
# 크롤링 완료: 마포구 아현동 - 19개 단지
# 크롤링 완료: 마포구 연남동 - 20개 단지
# 크롤링 완료: 마포구 염리동 - 12개 단지
# 크롤링 완료: 마포구 용강동 - 10개 단지
# 크롤링 완료: 마포구 중동 - 13개 단지
# 크롤링 완료: 마포구 창전동 - 14개 단지
# 크롤링 완료: 마포구 토정동 - 1개 단지
# 크롤링 완료: 마포구 하중동 - 1개 단지
# 크롤링 완료: 마포구 합정동 - 27개 단지
# 크롤링 완료: 마포구 현석동 - 6개 단지
# 마포구 데이터 저장 완료
# 크롤링 완료: 서대문구 남가좌동 - 17개 단지
# 크롤링 완료: 서대문구 냉천동 - 3개 단지
# 크롤링 완료: 서대문구 대현동 - 18개 단지
# 크롤링 완료: 서대문구 미근동 - 1개 단지
# 크롤링 완료: 서대문구 북가좌동 - 28개 단지
# 크롤링 완료: 서대문구 북아현동 - 26개 단지
# 크롤링 완료: 서대문구 연희동 - 54개 단지
# 크롤링 완료: 서대문구 영천동 - 1개 단지
# 크롤링 완료: 서대문구 창천동 - 19개 단지
# 크롤링 완료: 서대문구 천연동 - 4개 단지
# 크롤링 완료: 서대문구 충정로2가 - 3개 단지
# 크롤링 완료: 서대문구 충정로3가 - 16개 단지
# 크롤링 완료: 서대문구 합동 - 2개 단지
# 크롤링 완료: 서대문구 현저동 - 2개 단지
# 크롤링 완료: 서대문구 홍은동 - 75개 단지
# 크롤링 완료: 서대문구 홍제동 - 73개 단지
# 서대문구 데이터 저장 완료
# 크롤링 완료: 서초구 내곡동 - 2개 단지
# 크롤링 완료: 서초구 반포동 - 117개 단지
# 크롤링 완료: 서초구 방배동 - 275개 단지
# 크롤링 완료: 서초구 서초동 - 252개 단지
# 크롤링 완료: 서초구 신원동 - 5개 단지
# 크롤링 완료: 서초구 양재동 - 87개 단지
# 크롤링 완료: 서초구 우면동 - 17개 단지
# 크롤링 완료: 서초구 잠원동 - 77개 단지
# 서초구 데이터 저장 완료
# 크롤링 완료: 성동구 금호동1가 - 7개 단지
# 크롤링 완료: 성동구 금호동2가 - 3개 단지
# 크롤링 완료: 성동구 금호동3가 - 4개 단지
# 크롤링 완료: 성동구 금호동4가 - 11개 단지
# 크롤링 완료: 성동구 도선동 - 5개 단지
# 크롤링 완료: 성동구 마장동 - 22개 단지
# 크롤링 완료: 성동구 사근동 - 8개 단지
# 크롤링 완료: 성동구 상왕십리동 - 2개 단지
# 크롤링 완료: 성동구 성수동1가 - 31개 단지
# 크롤링 완료: 성동구 성수동2가 - 28개 단지
# 크롤링 완료: 성동구 송정동 - 6개 단지
# 크롤링 완료: 성동구 옥수동 - 21개 단지
# 크롤링 완료: 성동구 용답동 - 6개 단지
# 크롤링 완료: 성동구 응봉동 - 6개 단지
# 크롤링 완료: 성동구 하왕십리동 - 19개 단지
# 크롤링 완료: 성동구 행당동 - 21개 단지
# 크롤링 완료: 성동구 홍익동 - 10개 단지
# 성동구 데이터 저장 완료
# 크롤링 완료: 성북구 길음동 - 23개 단지
# 크롤링 완료: 성북구 돈암동 - 21개 단지
# 크롤링 완료: 성북구 동선동1가 - 3개 단지
# 크롤링 완료: 성북구 동선동3가 - 2개 단지
# 크롤링 완료: 성북구 동선동4가 - 4개 단지
# 크롤링 완료: 성북구 동선동5가 - 1개 단지
# 크롤링 완료: 성북구 동소문동1가 - 1개 단지
# 크롤링 완료: 성북구 동소문동2가 - 1개 단지
# 크롤링 완료: 성북구 동소문동4가 - 3개 단지
# 크롤링 완료: 성북구 동소문동5가 - 3개 단지
# 크롤링 완료: 성북구 동소문동6가 - 4개 단지
# 크롤링 완료: 성북구 동소문동7가 - 4개 단지
# 크롤링 완료: 성북구 보문동1가 - 1개 단지
# 크롤링 완료: 성북구 보문동2가 - 3개 단지
# 크롤링 완료: 성북구 보문동3가 - 2개 단지
# 크롤링 완료: 성북구 보문동4가 - 1개 단지
# 크롤링 완료: 성북구 보문동5가 - 1개 단지
# 크롤링 완료: 성북구 보문동6가 - 2개 단지
# 크롤링 완료: 성북구 보문동7가 - 2개 단지
# 크롤링 완료: 성북구 삼선동1가 - 1개 단지
# 크롤링 완료: 성북구 삼선동2가 - 2개 단지
# 크롤링 완료: 성북구 삼선동3가 - 6개 단지
# 크롤링 완료: 성북구 삼선동4가 - 2개 단지
# 크롤링 완료: 성북구 삼선동5가 - 3개 단지
# 크롤링 완료: 성북구 상월곡동 - 4개 단지
# 크롤링 완료: 성북구 석관동 - 14개 단지
# 크롤링 완료: 성북구 성북동 - 6개 단지
# 크롤링 완료: 성북구 성북동1가 - 2개 단지
# 크롤링 완료: 성북구 안암동1가 - 1개 단지
# 크롤링 완료: 성북구 안암동2가 - 1개 단지
# 크롤링 완료: 성북구 안암동3가 - 4개 단지
# 크롤링 완료: 성북구 안암동4가 - 1개 단지
# 크롤링 완료: 성북구 안암동5가 - 1개 단지
# 크롤링 완료: 성북구 장위동 - 18개 단지
# 크롤링 완료: 성북구 정릉동 - 52개 단지
# 크롤링 완료: 성북구 종암동 - 24개 단지
# 크롤링 완료: 성북구 하월곡동 - 32개 단지
# 성북구 데이터 저장 완료
# 크롤링 완료: 송파구 가락동 - 92개 단지
# 크롤링 완료: 송파구 거여동 - 40개 단지
# 크롤링 완료: 송파구 마천동 - 33개 단지
# 크롤링 완료: 송파구 문정동 - 55개 단지
# 크롤링 완료: 송파구 방이동 - 73개 단지
# 크롤링 완료: 송파구 삼전동 - 20개 단지
# 크롤링 완료: 송파구 석촌동 - 22개 단지
# 크롤링 완료: 송파구 송파동 - 53개 단지
# 크롤링 완료: 송파구 신천동 - 16개 단지
# 크롤링 완료: 송파구 오금동 - 68개 단지
# 크롤링 완료: 송파구 잠실동 - 31개 단지
# 크롤링 완료: 송파구 장지동 - 21개 단지
# 크롤링 완료: 송파구 풍납동 - 34개 단지
# 송파구 데이터 저장 완료
# 크롤링 완료: 양천구 목동 - 175개 단지
# 크롤링 완료: 양천구 신월동 - 239개 단지
# 크롤링 완료: 양천구 신정동 - 170개 단지
# 양천구 데이터 저장 완료
# 크롤링 완료: 영등포구 당산동 - 36개 단지
# 크롤링 완료: 영등포구 당산동1가 - 33개 단지
# 크롤링 완료: 영등포구 당산동2가 - 6개 단지
# 크롤링 완료: 영등포구 당산동3가 - 21개 단지
# 크롤링 완료: 영등포구 당산동4가 - 18개 단지
# 크롤링 완료: 영등포구 당산동5가 - 8개 단지
# 크롤링 완료: 영등포구 당산동6가 - 21개 단지
# 크롤링 완료: 영등포구 대림동 - 41개 단지
# 크롤링 완료: 영등포구 도림동 - 12개 단지
# 크롤링 완료: 영등포구 문래동1가 - 1개 단지
# 크롤링 완료: 영등포구 문래동2가 - 1개 단지
# 크롤링 완료: 영등포구 문래동3가 - 14개 단지
# 크롤링 완료: 영등포구 문래동4가 - 3개 단지
# 크롤링 완료: 영등포구 문래동5가 - 6개 단지
# 크롤링 완료: 영등포구 문래동6가 - 10개 단지
# 크롤링 완료: 영등포구 신길동 - 71개 단지
# 크롤링 완료: 영등포구 양평동1가 - 18개 단지
# 크롤링 완료: 영등포구 양평동2가 - 6개 단지
# 크롤링 완료: 영등포구 양평동3가 - 25개 단지
# 크롤링 완료: 영등포구 양평동4가 - 30개 단지
# 크롤링 완료: 영등포구 양평동5가 - 8개 단지
# 크롤링 완료: 영등포구 양평동6가 - 8개 단지
# 크롤링 완료: 영등포구 여의도동 - 25개 단지
# 크롤링 완료: 영등포구 영등포동 - 10개 단지
# 크롤링 완료: 영등포구 영등포동1가 - 21개 단지
# 크롤링 완료: 영등포구 영등포동2가 - 39개 단지
# 크롤링 완료: 영등포구 영등포동3가 - 3개 단지
# 크롤링 완료: 영등포구 영등포동4가 - 7개 단지
# 크롤링 완료: 영등포구 영등포동5가 - 6개 단지
# 크롤링 완료: 영등포구 영등포동6가 - 18개 단지
# 크롤링 완료: 영등포구 영등포동7가 - 32개 단지
# 크롤링 완료: 영등포구 영등포동8가 - 7개 단지
# 영등포구 데이터 저장 완료
# 크롤링 완료: 용산구 갈월동 - 2개 단지
# 크롤링 완료: 용산구 도원동 - 3개 단지
# 크롤링 완료: 용산구 동빙고동 - 8개 단지
# 크롤링 완료: 용산구 동자동 - 2개 단지
# 크롤링 완료: 용산구 문배동 - 14개 단지
# 크롤링 완료: 용산구 보광동 - 4개 단지
# 크롤링 완료: 용산구 산천동 - 2개 단지
# 크롤링 완료: 용산구 서빙고동 - 5개 단지
# 크롤링 완료: 용산구 신계동 - 1개 단지
# 크롤링 완료: 용산구 신창동 - 2개 단지
# 크롤링 완료: 용산구 용문동 - 5개 단지
# 크롤링 완료: 용산구 용산동2가 - 2개 단지
# 크롤링 완료: 용산구 용산동5가 - 1개 단지
# 크롤링 완료: 용산구 원효로1가 - 9개 단지
# 크롤링 완료: 용산구 원효로2가 - 4개 단지
# 크롤링 완료: 용산구 원효로3가 - 4개 단지
# 크롤링 완료: 용산구 원효로4가 - 4개 단지
# 크롤링 완료: 용산구 이촌동 - 42개 단지
# 크롤링 완료: 용산구 이태원동 - 20개 단지
# 크롤링 완료: 용산구 주성동 - 1개 단지
# 크롤링 완료: 용산구 청암동 - 2개 단지
# 크롤링 완료: 용산구 청파동1가 - 2개 단지
# 크롤링 완료: 용산구 청파동3가 - 5개 단지
# 크롤링 완료: 용산구 한강로1가 - 7개 단지
# 크롤링 완료: 용산구 한강로2가 - 9개 단지
# 크롤링 완료: 용산구 한강로3가 - 13개 단지
# 크롤링 완료: 용산구 한남동 - 63개 단지
# 크롤링 완료: 용산구 효창동 - 25개 단지
# 크롤링 완료: 용산구 후암동 - 15개 단지
# 용산구 데이터 저장 완료
# 크롤링 완료: 은평구 갈현동 - 46개 단지
# 크롤링 완료: 은평구 구산동 - 47개 단지
# 크롤링 완료: 은평구 녹번동 - 42개 단지
# 크롤링 완료: 은평구 대조동 - 73개 단지
# 크롤링 완료: 은평구 불광동 - 72개 단지
# 크롤링 완료: 은평구 수색동 - 15개 단지
# 크롤링 완료: 은평구 신사동 - 93개 단지
# 크롤링 완료: 은평구 역촌동 - 81개 단지
# 크롤링 완료: 은평구 응암동 - 162개 단지
# 크롤링 완료: 은평구 증산동 - 44개 단지
# 크롤링 완료: 은평구 진관동 - 40개 단지
# 은평구 데이터 저장 완료
# 크롤링 완료: 종로구 견지동 - 1개 단지
# 크롤링 완료: 종로구 관수동 - 1개 단지
# 크롤링 완료: 종로구 교북동 - 2개 단지
# 크롤링 완료: 종로구 구기동 - 8개 단지
# 크롤링 완료: 종로구 낙원동 - 1개 단지
# 크롤링 완료: 종로구 내수동 - 6개 단지
# 크롤링 완료: 종로구 당주동 - 2개 단지
# 크롤링 완료: 종로구 동숭동 - 1개 단지
# 크롤링 완료: 종로구 명륜1가 - 6개 단지
# 크롤링 완료: 종로구 명륜2가 - 4개 단지
# 크롤링 완료: 종로구 명륜3가 - 1개 단지
# 크롤링 완료: 종로구 무악동 - 6개 단지
# 크롤링 완료: 종로구 부암동 - 4개 단지
# 크롤링 완료: 종로구 사직동 - 2개 단지
# 크롤링 완료: 종로구 수송동 - 1개 단지
# 크롤링 완료: 종로구 숭인동 - 31개 단지
# 크롤링 완료: 종로구 신교동 - 1개 단지
# 크롤링 완료: 종로구 신문로1가 - 1개 단지
# 크롤링 완료: 종로구 신문로2가 - 2개 단지
# 크롤링 완료: 종로구 신영동 - 3개 단지
# 크롤링 완료: 종로구 연건동 - 1개 단지
# 크롤링 완료: 종로구 연지동 - 3개 단지
# 크롤링 완료: 종로구 옥인동 - 2개 단지
# 크롤링 완료: 종로구 이화동 - 1개 단지
# 크롤링 완료: 종로구 익선동 - 2개 단지
# 크롤링 완료: 종로구 인의동 - 1개 단지
# 크롤링 완료: 종로구 창신동 - 21개 단지
# 크롤링 완료: 종로구 청운동 - 2개 단지
# 크롤링 완료: 종로구 충신동 - 2개 단지
# 크롤링 완료: 종로구 통인동 - 1개 단지
# 크롤링 완료: 종로구 평동 - 1개 단지
# 크롤링 완료: 종로구 평창동 - 20개 단지
# 크롤링 완료: 종로구 필운동 - 2개 단지
# 크롤링 완료: 종로구 행촌동 - 1개 단지
# 크롤링 완료: 종로구 혜화동 - 1개 단지
# 크롤링 완료: 종로구 홍파동 - 1개 단지
# 크롤링 완료: 종로구 효제동 - 2개 단지
# 종로구 데이터 저장 완료
# 크롤링 완료: 중구 광희동2가 - 1개 단지
# 크롤링 완료: 중구 남대문로5가 - 1개 단지
# 크롤링 완료: 중구 남산동2가 - 1개 단지
# 크롤링 완료: 중구 남창동 - 1개 단지
# 크롤링 완료: 중구 만리동1가 - 4개 단지
# 크롤링 완료: 중구 만리동2가 - 2개 단지
# 크롤링 완료: 중구 무학동 - 1개 단지
# 크롤링 완료: 중구 묵정동 - 3개 단지
# 크롤링 완료: 중구 산림동 - 2개 단지
# 크롤링 완료: 중구 순화동 - 3개 단지
# 크롤링 완료: 중구 신당동 - 56개 단지
# 크롤링 완료: 중구 예장동 - 1개 단지
# 크롤링 완료: 중구 오장동 - 5개 단지
# 크롤링 완료: 중구 을지로5가 - 1개 단지
# 크롤링 완료: 중구 을지로6가 - 1개 단지
# 크롤링 완료: 중구 인현동2가 - 3개 단지
# 크롤링 완료: 중구 입정동 - 4개 단지
# 크롤링 완료: 중구 장충동1가 - 3개 단지
# 크롤링 완료: 중구 장충동2가 - 2개 단지
# 크롤링 완료: 중구 정동 - 3개 단지
# 크롤링 완료: 중구 주교동 - 1개 단지
# 크롤링 완료: 중구 중림동 - 4개 단지
# 크롤링 완료: 중구 충무로4가 - 2개 단지
# 크롤링 완료: 중구 충무로5가 - 3개 단지
# 크롤링 완료: 중구 필동1가 - 1개 단지
# 크롤링 완료: 중구 필동3가 - 1개 단지
# 크롤링 완료: 중구 황학동 - 40개 단지
# 크롤링 완료: 중구 회현동1가 - 8개 단지
# 크롤링 완료: 중구 회현동2가 - 1개 단지
# 크롤링 완료: 중구 흥인동 - 6개 단지
# 중구 데이터 저장 완료
# 크롤링 완료: 중랑구 망우동 - 56개 단지
# 크롤링 완료: 중랑구 면목동 - 139개 단지
# 크롤링 완료: 중랑구 묵동 - 56개 단지
# 크롤링 완료: 중랑구 상봉동 - 98개 단지
# 크롤링 완료: 중랑구 신내동 - 36개 단지
# 크롤링 완료: 중랑구 중화동 - 38개 단지
# 중랑구 데이터 저장 완료
